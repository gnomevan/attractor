# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !python -u /kaggle/input/datasets/gnomevan/tdaripser/experiment_L_tda.py --seeds 3
# Out:
# Using ripser for persistent homology (fast)
# ============================================================
# EXPERIMENT L: TOPOLOGICAL DATA ANALYSIS OF CNN TRAJECTORY
#   3 seeds × 7 LRs, 5000 steps
#   n_eval=100, output_every=5
#   PCA to 10D before TDA, max 400 points
#   TDA backend: ripser
# ============================================================
#   Device: cuda
#   Loading CIFAR-10...
# 100%|████████████████████████████████████████| 170M/170M [00:01<00:00, 86.3MB/s]
#   Finding EoS threshold...
#   λ_max ≈ 6.7622, EoS ≈ 0.2958
#
#   [1/21] 5% EoS, η=0.0148, seed=0 ETA: 0s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=94.7%, top-10 cumulative=100.0%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['0.0431', '0.0353', '0.0344'], gap ratio=1.22
#     H1: no features
#     H2: no features
#     Sharpness embedding: (56, 7), τ=4
#     Sharpness H0: 55 features, top=[3.425795555114746, 3.142117500305176]
#     Sharpness H1: 6 features, top=[0.23448467254638672, 0.08645057678222656]
#
#   [2/21] 5% EoS, η=0.0148, seed=1 ETA: 3752s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=94.3%, top-10 cumulative=100.0%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['0.0432', '0.0386', '0.0343'], gap ratio=1.12
#     H1: no features
#     H2: no features
#     Sharpness embedding: (62, 7), τ=3
#     Sharpness H0: 61 features, top=[2.0095038414001465, 1.6739280223846436]
#     Sharpness H1: 3 features, top=[0.11823463439941406, 0.02366340160369873]
#
#   [3/21] 5% EoS, η=0.0148, seed=2 ETA: 4806s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=95.3%, top-10 cumulative=100.0%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['0.0374', '0.0363', '0.0316'], gap ratio=1.03
#     H1: no features
#     H2: no features
#     Sharpness embedding: (74, 7), τ=1
#     Sharpness H0: 73 features, top=[1.5935927629470825, 1.591238260269165]
#     Sharpness H1: 19 features, top=[0.2865380644798279, 0.1982020139694214]
#
#   [4/21] 15% EoS, η=0.0444, seed=0 ETA: 5129s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=52.1%, top-10 cumulative=99.2%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['1.4413', '1.4094', '1.3438'], gap ratio=1.02
#     H1: 135 features, top lifetimes=['0.7430', '0.6716', '0.5980'], gap ratio=1.11
#     H2: 86 features, top lifetimes=['0.3339', '0.3064', '0.2834'], gap ratio=1.09
#     Sharpness embedding: (44, 7), τ=6
#     Sharpness H0: 43 features, top=[6.059533596038818, 4.836606502532959]
#     Sharpness H1: 7 features, top=[0.4386277198791504, 0.283733606338501]
#
#   [5/21] 15% EoS, η=0.0444, seed=1 ETA: 5167s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=58.4%, top-10 cumulative=99.6%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['1.3440', '1.2854', '1.2579'], gap ratio=1.05
#     H1: 99 features, top lifetimes=['0.8915', '0.6948', '0.6692'], gap ratio=1.28
#     H2: 38 features, top lifetimes=['0.2501', '0.2165', '0.2033'], gap ratio=1.16
#     Sharpness embedding: (44, 7), τ=6
#     Sharpness H0: 43 features, top=[5.207322120666504, 5.14547872543335]
#     Sharpness H1: 5 features, top=[0.2517991065979004, 0.24494218826293945]
#
#   [6/21] 15% EoS, η=0.0444, seed=2 ETA: 5056s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=60.0%, top-10 cumulative=99.5%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['1.4653', '1.4195', '1.3538'], gap ratio=1.03
#     H1: 86 features, top lifetimes=['0.8591', '0.6529', '0.6224'], gap ratio=1.32
#     H2: 26 features, top lifetimes=['0.3646', '0.2342', '0.1098'], gap ratio=1.56
#     Sharpness embedding: (44, 7), τ=6
#     Sharpness H0: 43 features, top=[4.106671333312988, 4.056779861450195]
#
#   [7/21] 20% EoS, η=0.0592, seed=0 ETA: 4860s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=48.9%, top-10 cumulative=97.7%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['1.8293', '1.7281', '1.6779'], gap ratio=1.06
#     H1: 264 features, top lifetimes=['0.6715', '0.6310', '0.6203'], gap ratio=1.06
#     H2: 207 features, top lifetimes=['0.3501', '0.3340', '0.3180'], gap ratio=1.05
#     Sharpness embedding: (50, 7), τ=5
#     Sharpness H0: 49 features, top=[3.3836281299591064, 2.956268310546875]
#     Sharpness H1: 14 features, top=[0.3788107633590698, 0.2709583044052124]
#
#   [8/21] 20% EoS, η=0.0592, seed=1 ETA: 4610s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=51.8%, top-10 cumulative=98.2%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['1.6065', '1.6064', '1.5962'], gap ratio=1.00
#     H1: 212 features, top lifetimes=['0.7055', '0.5664', '0.5518'], gap ratio=1.25
#     H2: 149 features, top lifetimes=['0.3349', '0.2870', '0.2371'], gap ratio=1.17
#     Sharpness embedding: (20, 6), τ=12
#     Sharpness H0: 19 features, top=[4.943933963775635, 3.3551950454711914]
#     Sharpness H1: 1 features, top=[0.14966773986816406]
#
#   [9/21] 20% EoS, η=0.0592, seed=2 ETA: 4326s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=52.9%, top-10 cumulative=97.6%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['1.6537', '1.6367', '1.6106'], gap ratio=1.01
#     H1: 222 features, top lifetimes=['0.6828', '0.6694', '0.6665'], gap ratio=1.02
#     H2: 164 features, top lifetimes=['0.4345', '0.2930', '0.2721'], gap ratio=1.48
#     Sharpness embedding: (40, 3), τ=20
#     Sharpness H0: 39 features, top=[2.6506588459014893, 2.293715000152588]
#     Sharpness H1: 3 features, top=[0.09700542688369751, 0.03620252013206482]
#
#   [10/21] 30% EoS, η=0.0887, seed=0 ETA: 4017s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=50.3%, top-10 cumulative=97.2%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['2.4823', '2.0500', '1.9235'], gap ratio=1.21
#     H1: 412 features, top lifetimes=['0.5841', '0.5604', '0.5507'], gap ratio=1.04
#     H2: 381 features, top lifetimes=['0.3496', '0.3273', '0.3110'], gap ratio=1.07
#     Sharpness embedding: (74, 7), τ=1
#     Sharpness H0: 73 features, top=[1.8104878664016724, 1.7996748685836792]
#     Sharpness H1: 47 features, top=[0.3392772674560547, 0.316788911819458]
#
#   [11/21] 30% EoS, η=0.0887, seed=1 ETA: 3690s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=51.3%, top-10 cumulative=97.2%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['2.0697', '1.9720', '1.7701'], gap ratio=1.05
#     H1: 377 features, top lifetimes=['0.6513', '0.6471', '0.5789'], gap ratio=1.01
#     H2: 386 features, top lifetimes=['0.3669', '0.3418', '0.3212'], gap ratio=1.07
#     Sharpness embedding: (74, 7), τ=1
#     Sharpness H0: 73 features, top=[2.0079269409179688, 1.1748535633087158]
#     Sharpness H1: 45 features, top=[0.2916300892829895, 0.2432883381843567]
#
#   [12/21] 30% EoS, η=0.0887, seed=2 ETA: 3350s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=53.9%, top-10 cumulative=96.8%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['2.0260', '1.9832', '1.9653'], gap ratio=1.02
#     H1: 368 features, top lifetimes=['0.8453', '0.5890', '0.5758'], gap ratio=1.44
#     H2: 298 features, top lifetimes=['0.3602', '0.3478', '0.3256'], gap ratio=1.04
#     Sharpness embedding: (50, 7), τ=5
#     Sharpness H0: 49 features, top=[1.789731502532959, 1.6919957399368286]
#     Sharpness H1: 22 features, top=[0.34010279178619385, 0.30277836322784424]
#
#   [13/21] 40% EoS, η=0.1183, seed=0 ETA: 2999s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=51.1%, top-10 cumulative=97.1%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['2.0642', '2.0217', '1.8946'], gap ratio=1.02
#     H1: 436 features, top lifetimes=['0.5842', '0.5630', '0.5605'], gap ratio=1.04
#     H2: 400 features, top lifetimes=['0.3528', '0.3081', '0.2933'], gap ratio=1.15
#     Sharpness embedding: (50, 7), τ=5
#     Sharpness H0: 49 features, top=[1.670850396156311, 1.6696044206619263]
#     Sharpness H1: 26 features, top=[0.2744992971420288, 0.2644122838973999]
#
#   [14/21] 40% EoS, η=0.1183, seed=1 ETA: 2640s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=52.4%, top-10 cumulative=97.1%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['1.9200', '1.9024', '1.8723'], gap ratio=1.01
#     H1: 425 features, top lifetimes=['0.6847', '0.6163', '0.6108'], gap ratio=1.11
#     H2: 422 features, top lifetimes=['0.3196', '0.3194', '0.3172'], gap ratio=1.00
#     Sharpness embedding: (62, 7), τ=3
#     Sharpness H0: 61 features, top=[1.5279985666275024, 1.496915578842163]
#     Sharpness H1: 24 features, top=[0.23414349555969238, 0.18290424346923828]
#
#   [15/21] 40% EoS, η=0.1183, seed=2 ETA: 2275s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=55.3%, top-10 cumulative=96.8%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['1.9256', '1.8749', '1.8321'], gap ratio=1.03
#     H1: 402 features, top lifetimes=['0.6852', '0.6488', '0.6378'], gap ratio=1.06
#     H2: 382 features, top lifetimes=['0.3053', '0.2997', '0.2985'], gap ratio=1.02
#     Sharpness embedding: (74, 7), τ=1
#     Sharpness H0: 73 features, top=[1.783894419670105, 1.6975833177566528]
#     Sharpness H1: 40 features, top=[0.2556905746459961, 0.2205820083618164]
#
#   [16/21] 60% EoS, η=0.1775, seed=0 ETA: 1904s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=50.6%, top-10 cumulative=96.8%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['2.0800', '2.0170', '2.0030'], gap ratio=1.03
#     H1: 393 features, top lifetimes=['0.6491', '0.6265', '0.6208'], gap ratio=1.04
#     H2: 313 features, top lifetimes=['0.3696', '0.3282', '0.3183'], gap ratio=1.13
#     Sharpness embedding: (62, 7), τ=3
#     Sharpness H0: 61 features, top=[1.6890490055084229, 1.525562047958374]
#     Sharpness H1: 35 features, top=[0.2197588086128235, 0.20436090230941772]
#
#   [17/21] 60% EoS, η=0.1775, seed=1 ETA: 1530s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=51.8%, top-10 cumulative=96.9%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['2.0313', '1.9645', '1.9477'], gap ratio=1.03
#     H1: 386 features, top lifetimes=['0.5459', '0.5355', '0.5151'], gap ratio=1.02
#     H2: 305 features, top lifetimes=['0.3231', '0.3118', '0.2772'], gap ratio=1.04
#     Sharpness embedding: (68, 7), τ=2
#     Sharpness H0: 67 features, top=[1.3019169569015503, 0.947044849395752]
#     Sharpness H1: 34 features, top=[0.2424551248550415, 0.20577532052993774]
#
#   [18/21] 60% EoS, η=0.1775, seed=2 ETA: 1152s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=54.4%, top-10 cumulative=96.9%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['2.3323', '2.2943', '2.0722'], gap ratio=1.02
#     H1: 356 features, top lifetimes=['0.5922', '0.5502', '0.5455'], gap ratio=1.08
#     H2: 296 features, top lifetimes=['0.3074', '0.2980', '0.2922'], gap ratio=1.03
#     Sharpness embedding: (74, 7), τ=1
#     Sharpness H0: 73 features, top=[1.3220956325531006, 1.3196781873703003]
#     Sharpness H1: 47 features, top=[0.268072247505188, 0.2514839172363281]
#
#   [19/21] 90% EoS, η=0.2662, seed=0 ETA: 770s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=48.5%, top-10 cumulative=96.3%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['2.8738', '2.3822', '2.3649'], gap ratio=1.21
#     H1: 316 features, top lifetimes=['0.4503', '0.4272', '0.4215'], gap ratio=1.05
#     H2: 160 features, top lifetimes=['0.3579', '0.2903', '0.2388'], gap ratio=1.23
#     Sharpness embedding: (74, 7), τ=1
#     Sharpness H0: 73 features, top=[1.1948705911636353, 1.167411208152771]
#     Sharpness H1: 39 features, top=[0.11705842614173889, 0.10164761543273926]
#
#   [20/21] 90% EoS, η=0.2662, seed=1 ETA: 386s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=49.3%, top-10 cumulative=96.6%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['2.3337', '2.2524', '2.2267'], gap ratio=1.04
#     H1: 288 features, top lifetimes=['0.4845', '0.4845', '0.4646'], gap ratio=1.00
#     H2: 164 features, top lifetimes=['0.3649', '0.3179', '0.2846'], gap ratio=1.15
#     Sharpness embedding: (68, 7), τ=2
#     Sharpness H0: 67 features, top=[1.0894399881362915, 1.087626576423645]
#     Sharpness H1: 17 features, top=[0.10733997821807861, 0.06409549713134766]
#
#   [21/21] 90% EoS, η=0.2662, seed=2 ETA: 0s
#     Trajectory: 800 points × 1000 dims
#     PCA: PC1=51.7%, top-10 cumulative=96.6%
#     Computing persistence on 10D trajectory...
#     H0: 399 features, top lifetimes=['2.3516', '2.3025', '2.2953'], gap ratio=1.02
#     H1: 294 features, top lifetimes=['0.6447', '0.5625', '0.5276'], gap ratio=1.15
#     H2: 165 features, top lifetimes=['0.3185', '0.3146', '0.2465'], gap ratio=1.01
#     Sharpness embedding: (56, 7), τ=4
#     Sharpness H0: 55 features, top=[0.6652231216430664, 0.6534403562545776]
#     Sharpness H1: 29 features, top=[0.16570788621902466, 0.10577237606048584]
#
# ============================================================
# EXPERIMENT L SUMMARY
# ============================================================
#
# frac_EoS   H₁ feat   H₁ top life    H₁ gap   H₂ feat    torus?
# ------------------------------------------------------------
#       5%         0.0        0.0000       0.0       0.0        no
#      15%       106.7        0.8312       1.2      50.0     maybe
#      20%       232.7        0.6866       1.1     173.3     maybe
#      30%       385.7        0.6936       1.2     355.0     maybe
#      40%       421.0        0.6514       1.1     401.3     maybe
#      60%       378.3        0.5957       1.0     304.7     maybe
#      90%       299.3        0.5265       1.1     163.0     maybe
#
#   Saved → results/tda_cifar10.json
#   Saved → figures/tda_cifar10.png
#
# Done.
